# %%
#https://ieeexplore.ieee.org/document/10549889

# %%
# !pip install openpyxl ssqueezepy pyt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting ssqueezepy
#   Downloading ssqueezepy-0.6.5-py3-none-any.whl.metadata (14 kB)
# Collecting pyt
#   Downloading pyt-1.0.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ssqueezepy) (1.24.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from ssqueezepy) (0.57.1+1.gb7ee25572)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ssqueezepy) (1.11.4)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->ssqueezepy) (0.40.1)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 19.3 MB/s eta 0:00:00
# Downloading ssqueezepy-0.6.5-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.2/127.2 kB 30.7 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pyt
#   Building wheel for pyt (setup.py) ... done
#   Created wheel for pyt: filename=pyt-1.0.5-py3-none-any.whl size=16716 sha256=a65b5a8f2528e9892e80f2615c8eac7fc8b698cb90ed6ddb613310962f4b0e31
#   Stored in directory: /home/work/.cache/pip/wheels/79/44/3a/ec16180c30a94673c22d6e12f30ae7f64bd1319df5395edd56
# Successfully built pyt
# Installing collected packages: pyt, et-xmlfile, ssqueezepy, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5 pyt-1.0.5 ssqueezepy-0.6.5

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 2025-01-22 04:36:15.242134: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-22 04:36:15.242211: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-22 04:36:15.242246: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 04:36:15.251820: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import keras.models
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
data = pd.read_csv("WISDM.csv", index_col=0)
data
# Out:
#          user-id activity        timestamp         X          Y         Z
# 0             33  Jogging   49105962326000 -0.694638  12.680544  0.503953
# 1             33  Jogging   49106062271000  5.012288  11.264028  0.953424
# 2             33  Jogging   49106112167000  4.903325  10.882658 -0.081722
# 3             33  Jogging   49106222305000 -0.612916  18.496431  3.023717
# 4             33  Jogging   49106332290000 -1.184970  12.108489  7.205164
# ...          ...      ...              ...       ...        ...       ...
# 1098199       19  Sitting  131623331483000  9.000000  -1.570000  1.690000
# 1098200       19  Sitting  131623371431000  9.040000  -1.460000  1.730000
# 1098201       19  Sitting  131623411592000  9.080000  -1.380000  1.690000
# 1098202       19  Sitting  131623491487000  9.000000  -1.460000  1.730000
# 1098203       19  Sitting  131623531465000  8.880000  -1.330000  1.610000
#
# [1098203 rows x 6 columns]

# %%
# mapping = {'Walking': 0, 'Jogging': 1, 'Upstairs': 2, 'Downstairs': 3, 'Sitting': 4, 'Standing': 5}

# # 레이블 인코딩
# data['ActivityEncoded'] = data['activity'].map(mapping)
# data

# %%
data['X'] = data['X'].astype('float')
data['Y'] = data['Y'].astype('float')
data['X'] = data['Z'].astype('float')

# %%
df = data.drop(['user-id', 'timestamp'], axis = 1).copy()
df.head()
# Out:
#   activity         X          Y         Z
# 0  Jogging  0.503953  12.680544  0.503953
# 1  Jogging  0.953424  11.264028  0.953424
# 2  Jogging -0.081722  10.882658 -0.081722
# 3  Jogging  3.023717  18.496431  3.023717
# 4  Jogging  7.205164  12.108489  7.205164

# %%
sns.countplot(x = "activity", data = df, order = df.activity.value_counts().index)
# Out:
# <Axes: xlabel='activity', ylabel='count'>

# %%
df['activity'].value_counts()
# Out:
# Walking       424397
# Jogging       342176
# Upstairs      122869
# Downstairs    100427
# Sitting        59939
# Standing       48395
# Name: activity, dtype: int64

# %%
Walking = df[df['activity']=='Walking'].copy()
Jogging = df[df['activity']=='Jogging'].copy()
Upstairs = df[df['activity']=='Upstairs'].copy()
Downstairs = df[df['activity']=='Downstairs'].copy()

# %%
dynamic_df = pd.DataFrame()
dynamic_df = pd.concat([dynamic_df, Walking, Jogging, Upstairs, Downstairs])
dynamic_df.shape
# Out:
# (989869, 4)

# %%
dynamic_df['activity'].value_counts()
# Out:
# Walking       424397
# Jogging       342176
# Upstairs      122869
# Downstairs    100427
# Name: activity, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
dynamic_df['label'] = label.fit_transform(dynamic_df['activity'])
dynamic_df.head()
# Out:
#     activity         X          Y         Z  label
# 597  Walking  2.792171   8.008764  2.792171      3
# 598  Walking  3.786457   8.621680  3.786457      3
# 599  Walking  1.307553  16.657684  1.307553      3
# 600  Walking -1.184970  10.760075 -1.184970      3
# 601  Walking -0.694638   9.234595 -0.694638      3

# %%
X = dynamic_df[['X', 'Y', 'Z']]
y = dynamic_df['label']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

scaled_X = pd.DataFrame(data = X, columns = ['X', 'Y', 'Z'])
scaled_X['label'] = y.values

scaled_X
# Out:
#                X         Y         Z  label
# 0       0.592824  0.073862  0.592824      3
# 1       0.806257  0.162515  0.806257      3
# 2       0.274137  1.324852  0.274137      3
# 3      -0.260907  0.471815 -0.260907      3
# 4      -0.155653  0.251168 -0.155653      3
# ...          ...       ...       ...    ...
# 989864  0.583772  0.062470  0.583772      0
# 989865  0.188798  0.279432  0.188798      0
# 989866  0.057856  0.988173  0.057856      0
# 989867 -0.599003  0.117434 -0.599003      0
# 989868 -0.169683 -0.558041 -0.169683      0
#
# [989869 rows x 4 columns]

# %%
from scipy import stats

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 128
STEP = 40

X_data, y_data = create_dataset(scaled_X[["X", "Y", "Z"]], scaled_X.label, TIME_STEPS,
                                  STEP)

trainX, testX,trainy, testy = train_test_split(X_data, y_data, test_size = 0.2, stratify=  y_data )
trainX, valX, trainy, valy  = train_test_split(trainX, trainy, test_size = 0.2, stratify=  trainy )
print(trainX.shape, trainy.shape)
print(testX.shape, testy.shape)
# Out:
# (15836, 128, 3) (15836, 1)
# (4949, 128, 3) (4949, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse_output = False)
enc = enc.fit(trainy)

trainy_one_hot = enc.transform(trainy)
testy_one_hot = enc.transform(testy)
valy_one_hot = enc.transform(valy)

print(trainX.shape, trainy_one_hot.shape, testX.shape, testy_one_hot.shape)
# Out:
# (15836, 128, 3) (15836, 4) (4949, 128, 3) (4949, 4)

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1606]
#  [   1 5474]
#  [   2 1966]
#  [   3 6790]]
# Test data label statistics::
# [[   0  502]
#  [   1 1711]
#  [   2  614]
#  [   3 2122]]

# %%
import os

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Lambda, Dot, Activation, Concatenate, Layer, RepeatVector, Add, Permute, Multiply

# KERAS_ATTENTION_DEBUG: If set to 1. Will switch to debug mode.
# In debug mode, the class Attention is no longer a Keras layer.
# What it means in practice is that we can have access to the internal values
# of each tensor. If we don't use debug, Keras treats the object
# as a layer, and we can only get the final output.
debug_flag = int(os.environ.get('KERAS_ATTENTION_DEBUG', 0))


# References:
# - https://arxiv.org/pdf/1508.04025.pdf (Luong).
# - https://arxiv.org/pdf/1409.0473.pdf (Bahdanau).
# - https://machinelearningmastery.com/the-bahdanau-attention-mechanism/ (Some more explanation).

class Attention(object if debug_flag else Layer):
    SCORE_LUONG = 'luong'
    SCORE_BAHDANAU = 'bahdanau'

    def __init__(self, units: int = 128, score: str = 'luong', **kwargs):
        super(Attention, self).__init__(**kwargs)
        if score not in {self.SCORE_LUONG, self.SCORE_BAHDANAU}:
            raise ValueError(f'Possible values for score are: [{self.SCORE_LUONG}] and [{self.SCORE_BAHDANAU}].')
        self.units = units
        self.score = score

    # noinspection PyAttributeOutsideInit
    def build(self, input_shape):
        input_dim = int(input_shape[-1])
        with K.name_scope(self.name if not debug_flag else 'attention'):
            # W in W*h_S.
            if self.score == self.SCORE_LUONG:
                self.luong_w = Dense(input_dim, use_bias=False, name='luong_w')
                # dot : last hidden state H_t and every hidden state H_s.
                self.luong_dot = Dot(axes=[1, 2], name='attention_score')
            else:
                # Dense implements the operation: output = activation(dot(input, kernel) + bias)
                self.bahdanau_v = Dense(1, use_bias=False, name='bahdanau_v')
                self.bahdanau_w1 = Dense(input_dim, use_bias=False, name='bahdanau_w1')
                self.bahdanau_w2 = Dense(input_dim, use_bias=False, name='bahdanau_w2')
                self.bahdanau_repeat = RepeatVector(input_shape[1])
                self.bahdanau_tanh = Activation('tanh', name='bahdanau_tanh')
                self.bahdanau_add = Add()

            self.h_t = Lambda(lambda x: x[:, -1, :], output_shape=(input_dim,), name='last_hidden_state')

            # exp / sum(exp) -> softmax.
            self.softmax_normalizer = Activation('softmax', name='attention_weight')

            # dot : score * every hidden state H_s.
            # dot product. SUM(v1*v2). H_s = every source hidden state.
            self.dot_context = Dot(axes=[1, 1], name='context_vector')

            # [Ct; ht]
            self.concat_c_h = Concatenate(name='attention_output')

            # x -> tanh(w_c(x))
            self.w_c = Dense(self.units, use_bias=False, activation='tanh', name='attention_vector')
        if not debug_flag:
            # debug: the call to build() is done in call().
            super(Attention, self).build(input_shape)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.units

    def __call__(self, inputs, training=None, **kwargs):
        if debug_flag:
            return self.call(inputs, training, **kwargs)
        else:
            return super(Attention, self).__call__(inputs, training, **kwargs)

    # noinspection PyUnusedLocal
    def call(self, inputs, training=None, **kwargs):
        """
        Many-to-one attention mechanism for Keras. Supports:
            - Luong's multiplicative style.
            - Bahdanau's additive style.
        @param inputs: 3D tensor with shape (batch_size, time_steps, input_dim).
        @param training: not used in this layer.
        @return: 2D tensor with shape (batch_size, units)
        @author: philipperemy, felixhao28.
        """
        h_s = inputs
        if debug_flag:
            self.build(h_s.shape)
        h_t = self.h_t(h_s)
        if self.score == self.SCORE_LUONG:
            # Luong's multiplicative style.
            score = self.luong_dot([h_t, self.luong_w(h_s)])
        else:
            # Bahdanau's additive style.
            self.bahdanau_w1(h_s)
            a1 = self.bahdanau_w1(h_t)
            a2 = self.bahdanau_w2(h_s)
            a1 = self.bahdanau_repeat(a1)
            score = self.bahdanau_tanh(self.bahdanau_add([a1, a2]))
            score = self.bahdanau_v(score)
            score = K.squeeze(score, axis=-1)

        alpha_s = self.softmax_normalizer(score)
        context_vector = self.dot_context([h_s, alpha_s])
        a_t = self.w_c(self.concat_c_h([context_vector, h_t]))
        return a_t

    def get_config(self):
        config = super(Attention, self).get_config()
        config.update({'units': self.units, 'score': self.score})
        return config

# %%
SINGLE_ATTENTION_VECTOR = False
INPUT_DIMS = 3

def attention_3d_block(inputs):
    # inputs.shape = (batch_size, time_steps, input_dim)
    input_dim = int(inputs.shape[2])
    a = inputs
    a = tf.keras.layers.Permute((2, 1))(inputs)
    #a = Reshape((input_dim, TIME_STEPS))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(input_dim, activation='softmax')(a)
    if SINGLE_ATTENTION_VECTOR:
        a = Lambda(lambda x: K.mean(x, axis=1), name='dim_reduction')(a)
        a = RepeatVector(input_dim)(a)
    a_probs = Permute((1, 2), name='attention_vec')(a)

    #output_attention_mul = merge([inputs, a_probs], name='attention_mul', mode='mul')
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

# Another way of writing the attention mechanism is suitable for the use of the above error source:https://blog.csdn.net/uhauha2929/article/details/80733255
def attention_3d_block2(inputs, single_attention_vector=False):
    # If the upper layer is LSTM, you need return_sequences=True
    # inputs.shape = (batch_size, time_steps, input_dim)
    time_steps = K.int_shape(inputs)[1]
    input_dim = K.int_shape(inputs)[2]
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='softmax')(a)
    if single_attention_vector:
        a = Lambda(lambda x: K.mean(x, axis=1))(a)
        a = RepeatVector(input_dim)(a)

    a_probs = Permute((2, 1))(a)
    # Multiplied by the attention weight, but there is no summation, it seems to have little effect
    # If you classify tasks, you can do Flatten expansion
    # element-wise
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

# %%
INPUT_DIMS = 3

# %%
#score='luong'
score='bahdanau'

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]
n_timesteps, n_features, n_outputs
# Out:
# (128, 3, 4)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dropout, Flatten

inputs= Input(shape=(n_timesteps,n_features))

lstm_out = LSTM(128, return_sequences=True)(inputs)
lstm_out = LSTM(128, return_sequences=True)(lstm_out)
lstm_out = LSTM(128, return_sequences=True)(lstm_out)
lstm_out = Dropout(0.3)(lstm_out)
attention_mul = attention_3d_block(lstm_out)
attention_mul = Flatten()(attention_mul)

##dense layer
dense = Dense(64, activation='relu')(attention_mul)
outputs = Dense(4, activation='softmax')(dense)
model = Model(inputs, outputs)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2025-01-22 04:36:28.504044: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:cd:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  lstm (LSTM)                 (None, 128, 128)             67584     ['input_1[0][0]']
#
#  lstm_1 (LSTM)               (None, 128, 128)             131584    ['lstm[0][0]']
#
#  lstm_2 (LSTM)               (None, 128, 128)             131584    ['lstm_1[0][0]']
#
#  dropout (Dropout)           (None, 128, 128)             0         ['lstm_2[0][0]']
#
#  permute (Permute)           (None, 128, 128)             0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 128, 128)             16512     ['permute[0][0]']
#
#  attention_vec (Permute)     (None, 128, 128)             0         ['dense[0][0]']
#
#  multiply (Multiply)         (None, 128, 128)             0         ['dropout[0][0]',
#                                                                      'attention_vec[0][0]']
#
#  flatten (Flatten)           (None, 16384)                0         ['multiply[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   1048640   ['flatten[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    260       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1396164 (5.33 MB)
# Trainable params: 1396164 (5.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
import math
import time
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping()

start = time.time()
#model_history=model.fit(X_train, y_train_one_hot, epochs=300, batch_size=32, validation_data=(X_val,y_val_one_hot), callbacks = [early_stopping])
model_history=model.fit(trainX, trainy_one_hot, epochs=100, batch_size=32, validation_data=(valX,valy_one_hot))


end = time.time()
print(f"{end - start:.5f} sec")
# Out:
# Epoch 1/100
# 2025-01-22 04:36:33.065167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2025-01-22 04:36:33.904020: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f46e0003300 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-01-22 04:36:33.904051: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2025-01-22 04:36:33.909178: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-01-22 04:36:33.990091: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 495/495 [==============================] - 18s 26ms/step - loss: 0.8150 - accuracy: 0.7155 - val_loss: 0.6308 - val_accuracy: 0.7797
# Epoch 2/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.4503 - accuracy: 0.8323 - val_loss: 0.3105 - val_accuracy: 0.8932
# Epoch 3/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.2289 - accuracy: 0.9206 - val_loss: 0.1786 - val_accuracy: 0.9374
# Epoch 4/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.1605 - accuracy: 0.9456 - val_loss: 0.1387 - val_accuracy: 0.9591
# Epoch 5/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.1150 - accuracy: 0.9627 - val_loss: 0.1373 - val_accuracy: 0.9543
# Epoch 6/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.1008 - accuracy: 0.9668 - val_loss: 0.0916 - val_accuracy: 0.9697
# Epoch 7/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0723 - accuracy: 0.9763 - val_loss: 0.0921 - val_accuracy: 0.9672
# Epoch 8/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0668 - accuracy: 0.9763 - val_loss: 0.1118 - val_accuracy: 0.9659
# Epoch 9/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0579 - accuracy: 0.9809 - val_loss: 0.0668 - val_accuracy: 0.9755
# Epoch 10/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0353 - accuracy: 0.9879 - val_loss: 0.0476 - val_accuracy: 0.9831
# Epoch 11/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0374 - accuracy: 0.9886 - val_loss: 0.0743 - val_accuracy: 0.9745
# Epoch 12/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.0610 - val_accuracy: 0.9790
# Epoch 13/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0293 - accuracy: 0.9898 - val_loss: 0.0515 - val_accuracy: 0.9826
# Epoch 14/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0309 - accuracy: 0.9903 - val_loss: 0.0484 - val_accuracy: 0.9828
# Epoch 15/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0164 - accuracy: 0.9952 - val_loss: 0.0506 - val_accuracy: 0.9846
# Epoch 16/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0396 - val_accuracy: 0.9856
# Epoch 17/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.0465 - val_accuracy: 0.9841
# Epoch 18/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0198 - accuracy: 0.9939 - val_loss: 0.0411 - val_accuracy: 0.9864
# Epoch 19/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.0449 - val_accuracy: 0.9859
# Epoch 20/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0176 - accuracy: 0.9956 - val_loss: 0.0389 - val_accuracy: 0.9853
# Epoch 21/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.1015 - val_accuracy: 0.9775
# Epoch 22/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 0.0380 - val_accuracy: 0.9879
# Epoch 23/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0473 - val_accuracy: 0.9859
# Epoch 24/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0247 - val_accuracy: 0.9924
# Epoch 25/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.0589 - val_accuracy: 0.9818
# Epoch 26/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0340 - val_accuracy: 0.9889
# Epoch 27/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0450 - val_accuracy: 0.9889
# Epoch 28/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0713 - val_accuracy: 0.9755
# Epoch 29/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.0356 - val_accuracy: 0.9884
# Epoch 30/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0301 - val_accuracy: 0.9907
# Epoch 31/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0320 - val_accuracy: 0.9896
# Epoch 32/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.0632 - val_accuracy: 0.9793
# Epoch 33/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0489 - val_accuracy: 0.9874
# Epoch 34/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0435 - val_accuracy: 0.9896
# Epoch 35/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0891 - val_accuracy: 0.9800
# Epoch 36/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0389 - val_accuracy: 0.9896
# Epoch 37/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0528 - val_accuracy: 0.9853
# Epoch 38/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1009 - val_accuracy: 0.9800
# Epoch 39/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0610 - val_accuracy: 0.9848
# Epoch 40/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0651 - val_accuracy: 0.9831
# Epoch 41/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0393 - val_accuracy: 0.9876
# Epoch 42/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0292 - val_accuracy: 0.9924
# Epoch 43/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.0735 - val_accuracy: 0.9775
# Epoch 44/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0246 - val_accuracy: 0.9927
# Epoch 45/100
# 495/495 [==============================] - 12s 24ms/step - loss: 3.3927e-04 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9944
# Epoch 46/100
# 495/495 [==============================] - 12s 24ms/step - loss: 1.4227e-04 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9947
# Epoch 47/100
# 495/495 [==============================] - 12s 24ms/step - loss: 8.5455e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9944
# Epoch 48/100
# 495/495 [==============================] - 12s 25ms/step - loss: 1.1200e-04 - accuracy: 0.9999 - val_loss: 0.0338 - val_accuracy: 0.9922
# Epoch 49/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0276 - accuracy: 0.9923 - val_loss: 0.0281 - val_accuracy: 0.9917
# Epoch 50/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0304 - val_accuracy: 0.9912
# Epoch 51/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 52/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0299 - val_accuracy: 0.9896
# Epoch 53/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0588 - val_accuracy: 0.9879
# Epoch 54/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0370 - val_accuracy: 0.9912
# Epoch 55/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 56/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0466 - val_accuracy: 0.9871
# Epoch 57/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0604 - val_accuracy: 0.9889
# Epoch 58/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.0377 - val_accuracy: 0.9899
# Epoch 59/100
# 495/495 [==============================] - 12s 24ms/step - loss: 3.1417e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9929
# Epoch 60/100
# 495/495 [==============================] - 12s 24ms/step - loss: 9.7277e-05 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9929
# Epoch 61/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0881 - val_accuracy: 0.9790
# Epoch 62/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0205 - accuracy: 0.9941 - val_loss: 0.0227 - val_accuracy: 0.9939
# Epoch 63/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0326 - val_accuracy: 0.9919
# Epoch 64/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0495 - val_accuracy: 0.9879
# Epoch 65/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0293 - val_accuracy: 0.9927
# Epoch 66/100
# 495/495 [==============================] - 12s 25ms/step - loss: 5.0116e-04 - accuracy: 0.9999 - val_loss: 0.0528 - val_accuracy: 0.9881
# Epoch 67/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0367 - val_accuracy: 0.9917
# Epoch 68/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.0255 - val_accuracy: 0.9932
# Epoch 69/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0323 - val_accuracy: 0.9924
# Epoch 70/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0294 - val_accuracy: 0.9924
# Epoch 71/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0266 - val_accuracy: 0.9934
# Epoch 72/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.0262 - val_accuracy: 0.9942
# Epoch 73/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0563 - val_accuracy: 0.9861
# Epoch 74/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0284 - val_accuracy: 0.9919
# Epoch 75/100
# 495/495 [==============================] - 12s 24ms/step - loss: 4.2243e-04 - accuracy: 0.9998 - val_loss: 0.0246 - val_accuracy: 0.9932
# Epoch 76/100
# 495/495 [==============================] - 12s 24ms/step - loss: 1.4446e-04 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9937
# Epoch 77/100
# 495/495 [==============================] - 12s 24ms/step - loss: 2.1761e-04 - accuracy: 0.9999 - val_loss: 0.0286 - val_accuracy: 0.9927
# Epoch 78/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.0286 - val_accuracy: 0.9932
# Epoch 79/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0234 - val_accuracy: 0.9924
# Epoch 80/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0255 - val_accuracy: 0.9939
# Epoch 81/100
# 495/495 [==============================] - 12s 25ms/step - loss: 0.0075 - accuracy: 0.9985 - val_loss: 0.0653 - val_accuracy: 0.9861
# Epoch 82/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0495 - val_accuracy: 0.9899
# Epoch 83/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0370 - val_accuracy: 0.9919
# Epoch 84/100
# 495/495 [==============================] - 12s 24ms/step - loss: 8.0675e-04 - accuracy: 0.9999 - val_loss: 0.0359 - val_accuracy: 0.9922
# Epoch 85/100
# 495/495 [==============================] - 12s 24ms/step - loss: 1.1399e-04 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9942
# Epoch 86/100
# 495/495 [==============================] - 12s 24ms/step - loss: 9.2197e-05 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9939
# Epoch 87/100
# 495/495 [==============================] - 12s 25ms/step - loss: 3.9867e-05 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9939
# Epoch 88/100
# 495/495 [==============================] - 12s 25ms/step - loss: 2.2173e-05 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9942
# Epoch 89/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0159 - accuracy: 0.9961 - val_loss: 0.0312 - val_accuracy: 0.9901
# Epoch 90/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0287 - val_accuracy: 0.9924
# Epoch 91/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0267 - val_accuracy: 0.9927
# Epoch 92/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0303 - val_accuracy: 0.9929
# Epoch 93/100
# 495/495 [==============================] - 12s 24ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0224 - val_accuracy: 0.9939
# Epoch 94/100
# 495/495 [==============================] - 12s 25ms/step - loss: 4.2086e-04 - accuracy: 0.9999 - val_loss: 0.0227 - val_accuracy: 0.9947
# Epoch 95/100
# 495/495 [==============================] - 12s 25ms/step - loss: 1.9690e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9942
# Epoch 96/100
# 495/495 [==============================] - 12s 24ms/step - loss: 5.1785e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9949
# Epoch 97/100
# 495/495 [==============================] - 12s 24ms/step - loss: 4.6261e-05 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9942
# Epoch 98/100
# 495/495 [==============================] - 12s 24ms/step - loss: 2.1660e-05 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9944
# Epoch 99/100
# 495/495 [==============================] - 12s 24ms/step - loss: 1.5841e-05 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9944
# Epoch 100/100
# 495/495 [==============================] - 12s 24ms/step - loss: 1.1937e-05 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9944
# 1217.84447 sec

# %%
loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import numpy as np

# 예측 수행
predy = model.predict(testX)
predy = np.argmax(predy, axis=-1)  # 가장 확률이 높은 클래스를 선택

# 테스트 라벨 (One-Hot Encoding → 정수형 라벨 변환)
testy = np.argmax(testy_one_hot, axis=-1)  # 테스트 레이블 변환

# 라벨 정의
LABELS = ['Walking', 'Jogging', 'Upstairs', 'Downstairs']

# 혼동 행렬 생성
cm = confusion_matrix(testy, predy)

# 혼동 행렬 시각화
plot_confusion_matrix(conf_mat=cm, class_names=LABELS, show_normed=True, figsize=(7,7))

# 성능 보고서 출력
print("Classification Report:")
print(classification_report(testy, predy, target_names=LABELS))

# 정확도 출력
accuracy = accuracy_score(testy, predy)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 155/155 [==============================] - 2s 9ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#      Walking       0.99      0.98      0.99       502
#      Jogging       1.00      1.00      1.00      1711
#     Upstairs       0.98      0.99      0.99       614
#   Downstairs       1.00      1.00      1.00      2122
#
#     accuracy                           1.00      4949
#    macro avg       0.99      0.99      0.99      4949
# weighted avg       1.00      1.00      1.00      4949
#
# Test Accuracy: 1.00

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
# Out:
# [[ 494    2    6    0]
#  [   1 1707    2    1]
#  [   4    0  610    0]
#  [   1    2    2 2117]]
# 0.9957567185289957
# 0.995760200729811
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       502
#            1       1.00      1.00      1.00      1711
#            2       0.98      0.99      0.99       614
#            3       1.00      1.00      1.00      2122
#
#     accuracy                           1.00      4949
#    macro avg       0.99      0.99      0.99      4949
# weighted avg       1.00      1.00      1.00      4949
